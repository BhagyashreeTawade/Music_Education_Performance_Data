# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/shree/.vscode/python/data analyst projects/Music/music_education_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Student_ID           100 non-null    object
#  1   Age                  100 non-null    int64
#  2   Gender               100 non-null    object
#  3   Class_Level          100 non-null    object
#  4   Accuracy             100 non-null    float64
#  5   Rhythm               100 non-null    float64
#  6   Tempo                100 non-null    float64
#  7   Pitch_Accuracy       100 non-null    float64
#  8   Duration             100 non-null    float64
#  9   Volume               100 non-null    float64
#  10  Heart_Rate           100 non-null    float64
#  11  Blood_Pressure       100 non-null    float64
#  12  Stress_Level         100 non-null    int64
#  13  Engagement_Level     100 non-null    int64
#  14  Focus_Time           100 non-null    float64
# ...

# %%
df.head()
# Out:
#   Student_ID  Age  Gender   Class_Level   Accuracy     Rhythm       Tempo  \
# 0       S001   12  Female  Intermediate  71.053342  94.391587  142.863298
# 1       S002   11    Male      Advanced  77.352080  72.841144  142.035970
# 2       S003   13  Female  Intermediate  93.776395  94.781988  110.298237
# 3       S004   16  Female  Intermediate  77.101801  90.951063  100.547725
# 4       S005   11    Male      Beginner  80.318380  72.558753  175.980186
#
#    Pitch_Accuracy    Duration     Volume  ...  Stress_Level  Engagement_Level  \
# 0       88.828261  336.481857  86.428281  ...            10                 5
# 1       87.043906  371.244505  57.301702  ...             2                 4
# 2       92.283188  481.536745  83.494998  ...             3                 1
# 3       99.515410  259.091623  61.625075  ...             7                 5
# 4       85.663472  200.832085  71.774177  ...             5                10
#
# ...

# %%
df.describe()
# Out:
#               Age    Accuracy      Rhythm       Tempo  Pitch_Accuracy  \
# count  100.000000  100.000000  100.000000  100.000000      100.000000
# mean    13.530000   83.696677   85.559333  136.724994       90.540340
# std      2.337464    8.809481    8.506669   25.747350        5.861590
# min     10.000000   70.025969   71.051253   90.403546       80.296075
# 25%     11.750000   75.655089   78.153848  114.754370       85.703179
# 50%     13.500000   82.739047   85.571346  138.848090       90.328815
# 75%     16.000000   92.121121   92.974344  156.049853       95.379560
# max     17.000000   99.621783   99.837140  178.266168       99.954110
#
#          Duration      Volume  Heart_Rate  Blood_Pressure  Stress_Level  \
# count  100.000000  100.000000  100.000000      100.000000    100.000000
# mean   366.513294   74.557013   80.995748      120.106621      5.670000
# std    127.509080   13.546720   11.280124        6.037906      2.693258
# ...

# %% [markdown]
# 1.How many male and female students are there ?

# %%
gender_counts = df['Gender'].value_counts()
gender_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=['lightblue', 'pink'], figsize=(6, 6))
plt.title('Gender Distribution')
plt.ylabel('')  # Removes default y-axis label
plt.show()

# %% [markdown]
# 2.what factors most influence the performance score ?

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='Performance_Score', data=df)
plt.title('Age vs Performance Score')
plt.xlabel('Age')
plt.ylabel('Performance Score')
plt.show()

# %% [markdown]
# 3.difference in performance score between male and female

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x="Gender",y="Performance_Score",data=df)
plt.title("Performance Score by Gender")
plt.xlabel("Gender")
plt.ylabel("Performance Score")
plt.show()

# %% [markdown]
# 4.average engagement score for students across diff class level

# %%
average_engegment = df.groupby("Class_Level")["Engagement_Score"].mean()
average_engegment.plot(kind="bar",figsize=(8,6),color="Red")

plt.title('Average Engagement Score by Class Level')
plt.xlabel('Class Level')
plt.ylabel('Average Engagement Score')
plt.show()

# %% [markdown]
# 5.average accuracy by lesson type

# %%
avg_accuracy_by_lesson_type = df.groupby('Lesson_Type')['Accuracy'].mean()
avg_accuracy_by_lesson_type.plot(kind="bar",figsize=(8,6),color="lightgreen")
plt.title("Average Accuracy by Lesson Type")
plt.xlabel("Lesson Type")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# 6.How do students blood pressure level changed across diff lesoon type ?

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Lesson_Type',y='Blood_Pressure',data=df)
plt.title("Blood Pressure by Lesson Type")
plt.xlabel("Lesson Type")
plt.ylabel("Blood_Pressure")
plt.show()

# %% [raw]
# 7.How does performance vary across diff class levels

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Class_Level',y='Performance_Score',data=df)
plt.title("Performance score by class level")
plt.xlabel("Class level")
plt.ylabel("Performance Score")
plt.show()

# %%
#8.Average stress and Average Engagement score
avg_stress_level = df["Stress_Level"].mean()
avg_engagement_score = df["Engagement_Score"].mean()

data = {
    "Category": ["Stress_Level", "Engagement_Score"],
    "Average": [avg_stress_level, avg_engagement_score]
}
chart_df = pd.DataFrame(data)


plt.bar(chart_df["Category"],chart_df["Average"],color=["blue","green"])
plt.figure(figsize=(8,6))
plt.title("Average Stress Level and Average Engagement Score")
plt.xlabel("Category")
plt.ylabel("Average")
plt.show()

# %% [markdown]
# 8.Average stress and Average Engagement score

# %%
avg_stress_level = df["Stress_Level"].mean()
avg_engagement_score = df["Engagement_Score"].mean()

data = {
    "Category": ["Stress_Level", "Engagement_Score"],
    "Average": [avg_stress_level, avg_engagement_score]
}
chart_df = pd.DataFrame(data)

plt.figure(figsize=(8, 6))  
plt.bar(chart_df["Category"], chart_df["Average"], color=["blue", "green"])
plt.title("Average Stress Level and Average Engagement Score") 
plt.xlabel("Category")  
plt.ylabel("Average") 
plt.show()

# %% [markdown]
# 9.Distribution of Instrument type by Gender

# %%
#group by Instrument_Type and Gender, and count the occurrences
grouped_data = df.groupby(['Instrument_Type', 'Gender']).size().unstack()

grouped_data.plot(kind="bar",figsize=(8,6),colormap="viridis",edgecolor="black")
plt.title("Distribution of instrument type by Gender")
plt.xlabel("Instrument Type")
plt.ylabel('Count',)
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.tight_layout()
plt.show()

# %% [markdown]
# 10.What is the age distribution of students?

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Age'], bins=8, color='lightgreen', edgecolor='black')
plt.title('Age Distribution of Students', fontsize=14)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.show()

# %% [markdown]
# 11.What is the tempo distribution?

# %%
sns.kdeplot(df['Tempo'], fill=True, color='purple')
plt.title('Tempo Distribution', fontsize=14)
plt.xlabel('Tempo', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.show()
